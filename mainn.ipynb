# %%
import pandas as pd  

sentim = pd.read_csv('sentiments.txt', sep = ';', names = ['sentence','emotion'])
print(sentim.head())
print(sentim.info())
# Out:
#                                             sentence  emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sentence  16000 non-null  object
#  1   emotion   16000 non-null  object
# dtypes: object(2)
# memory usage: 250.1+ KB
# None

# %%
print(sentim['emotion'].value_counts())

#sentim.loc[sentim['emotion'] == 'joy', 'emotion'] = 1

#print(sentim['emotion'].value_counts())

sentim.replace({'joy': 1, 'love': 1, 'surprise': 1, 'sadness': 0, 'anger': 0, 'fear': 0}, inplace = True)
print(sentim['emotion'].value_counts())
# Out:
# emotion
# joy         5362
# sadness     4666
# anger       2159
# fear        1937
# love        1304
# surprise     572
# Name: count, dtype: int64
# emotion
# 0    8762
# 1    7238
# Name: count, dtype: int64
# C:\Users\simon\AppData\Local\Temp\ipykernel_3620\1475437958.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sentim.replace({'joy': 1, 'love': 1, 'surprise': 1, 'sadness': 0, 'anger': 0, 'fear': 0}, inplace = True)

# %%
import re  
import nltk   

nltk.download('stopwords')
nltk.download('wordnet')

from nltk.corpus import stopwords  
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\simon\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\simon\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
lemm = WordNetLemmatizer

def transformtxt(txt):
    stop = set(stopwords.words('english'))
    newtxt = []

    for sentence in txt:
        sentence = re.sub('[^a-zA-z]', ' ', sentence)
        sentence = sentence.lower()
        sentence = sentence.split()

        newwords = []

        for word in sentence:
            print(word)
            if word not in stop:
                newword = lemm.lemmatize(word)
                newwords.append(newword)

        newsentence = ' '.join(newwords)
        newtxt.append(newsentence)
    return newtxt

# %%
x = sentim['sentence']
y = sentim['emotion']

# %%
newx = transformtxt(x)

print(newx[0:10])
# Out:
# i
# didnt
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 newx = transformtxt(x)
#       3 print(newx[0:10])
#
# Cell In[15], line 17, in transformtxt(txt)
#      15     print(word)
#      16     if word not in stop:
# ---> 17         newword = lemm.lemmatize(word)
#      18         newwords.append(newword)
#      20 newsentence = ' '.join(newwords)
#
# TypeError: WordNetLemmatizer.lemmatize() missing 1 required positional argument: 'word'
